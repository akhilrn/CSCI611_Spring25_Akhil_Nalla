# %%
# !pip install ultralytics opencv-python numpy torch torchvision torchaudio
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.3/949.3 kB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 64.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 46.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 39.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/best.pt") # Load pre-trained YOLO model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-5a1024c7f099> in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2 model = YOLO("/content/drive/MyDrive/best.pt") # Load pre-trained YOLO model
#
# ModuleNotFoundError: No module named 'ultralytics'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
result=model.predict("/content/drive/MyDrive/seg0.mp4",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-479ef2728821> in <cell line: 0>()
# ----> 1 result=model.predict("/content/drive/MyDrive/seg0.mp4",save=True)
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
# ...

# %%
result=model.predict("/content/drive/MyDrive/seg4.mp4",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/300) /content/drive/MyDrive/seg4.mp4: 384x640 1 car, 87.5ms
# video 1/1 (frame 2/300) /content/drive/MyDrive/seg4.mp4: 384x640 2 buss, 1 car, 10.4ms
# video 1/1 (frame 3/300) /content/drive/MyDrive/seg4.mp4: 384x640 1 bus, 1 car, 10.2ms
# video 1/1 (frame 4/300) /content/drive/MyDrive/seg4.mp4: 384x640 1 car, 10.4ms
# video 1/1 (frame 5/300) /content/drive/MyDrive/seg4.mp4: 384x640 1 car, 9.3ms
# ...

# %%
result=model.predict("/content/drive/MyDrive/Traffic_signs_detector.v2i.yolov8/test/images/-7Zw87QNwuTBHOAgGBkYaQ_jpg.rf.8b0c72467dda61958d1bfa3b8cde0de3.jpg",save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Traffic_signs_detector.v2i.yolov8/test/images/-7Zw87QNwuTBHOAgGBkYaQ_jpg.rf.8b0c72467dda61958d1bfa3b8cde0de3.jpg: 640x640 (no detections), 11.2ms
# Speed: 4.3ms preprocess, 11.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
result=model.predict("/content/drive/MyDrive/seg2.mp4",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/300) /content/drive/MyDrive/seg2.mp4: 384x640 (no detections), 8.3ms
# video 1/1 (frame 2/300) /content/drive/MyDrive/seg2.mp4: 384x640 (no detections), 9.8ms
# video 1/1 (frame 3/300) /content/drive/MyDrive/seg2.mp4: 384x640 (no detections), 10.5ms
# video 1/1 (frame 4/300) /content/drive/MyDrive/seg2.mp4: 384x640 (no detections), 10.5ms
# ...

# %%
result=model.predict("/content/drive/MyDrive/seg7.mp4",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/300) /content/drive/MyDrive/seg7.mp4: 384x640 1 car, 9.7ms
# video 1/1 (frame 2/300) /content/drive/MyDrive/seg7.mp4: 384x640 1 car, 79.0ms
# video 1/1 (frame 3/300) /content/drive/MyDrive/seg7.mp4: 384x640 1 car, 9.3ms
# video 1/1 (frame 4/300) /content/drive/MyDrive/seg7.mp4: 384x640 2 cars, 15.7ms
# video 1/1 (frame 5/300) /content/drive/MyDrive/seg7.mp4: 384x640 1 car, 7.5ms
# ...

# %%
result=model.predict("/content/drive/MyDrive/seg7.mp4",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/300) /content/drive/MyDrive/seg7.mp4: 384x640 1 car, 112.5ms
# video 1/1 (frame 2/300) /content/drive/MyDrive/seg7.mp4: 384x640 1 car, 21.6ms
# video 1/1 (frame 3/300) /content/drive/MyDrive/seg7.mp4: 384x640 1 car, 9.6ms
# video 1/1 (frame 4/300) /content/drive/MyDrive/seg7.mp4: 384x640 2 cars, 21.9ms
# video 1/1 (frame 5/300) /content/drive/MyDrive/seg7.mp4: 384x640 1 car, 22.8ms
# ...

# %%
result=model.predict("/content/drive/MyDrive/seg10.mp4",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/222) /content/drive/MyDrive/seg10.mp4: 384x640 (no detections), 93.2ms
# video 1/1 (frame 2/222) /content/drive/MyDrive/seg10.mp4: 384x640 (no detections), 10.5ms
# video 1/1 (frame 3/222) /content/drive/MyDrive/seg10.mp4: 384x640 (no detections), 10.3ms
# video 1/1 (frame 4/222) /content/drive/MyDrive/seg10.mp4: 384x640 1 car, 10.3ms
# ...

# %%
result=model.predict("/content/drive/MyDrive/seg5.mp4",save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/300) /content/drive/MyDrive/seg5.mp4: 384x640 1 bus, 1 car, 7.3ms
# video 1/1 (frame 2/300) /content/drive/MyDrive/seg5.mp4: 384x640 1 bus, 1 car, 40.8ms
# video 1/1 (frame 3/300) /content/drive/MyDrive/seg5.mp4: 384x640 1 bus, 1 car, 23.4ms
# video 1/1 (frame 4/300) /content/drive/MyDrive/seg5.mp4: 384x640 1 bus, 1 car, 10.2ms
# video 1/1 (frame 5/300) /content/drive/MyDrive/seg5.mp4: 384x640 1 bus, 1 car, 30.0ms
# ...
